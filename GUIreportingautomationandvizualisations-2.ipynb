# %% [markdown]
# <center><b>Data Guide</b></center><br>
# <br><b>Terms Definition</b>:<br>
# <br><span style="color:#0000A0;">This Program was originally used for institutional research. Please ignore raw code variable names.</span>
# <br><i><span style="color:#800000;">This program utilizes excel sheet "ConsumerDummyData". This program is an example of a user interface in which the user can check KPI's of a particular product. This program generates reportings as well visuals needed for that product KPI's. For this example the program generates reports on how well a product is reaching consumer compared to the product line and brand totals.</span></i>
# <br><b>Inputs for UI fields are listed below simply copy and paste into corresponding fields:</b>:<br>
# <br>1. Region = G
# <br>2. List of Fiscal Years = y13,y14,y15,y16
# <br>3. Product Name = Product1 (you can also enter Product2, Product3, or Product4)<br>
# <br><i><span style="color:#800000;">To run generate reports for additional products utilizing the same input excel sheet and fiscal years simply replace the current product name with a new one and then hit the "Run Program" button.</span></i>

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>

# %%
from IPython.display import Javascript, display
from ipywidgets import widgets
from ipywidgets import FileUpload
import warnings
warnings.filterwarnings('ignore')

layout = widgets.Layout(width='auto', height='40px') #set width and height
style = {'description_width': 'initial',
        'description_heighth': '80px'}

# #ask user to upload Excel File
# upload = FileUpload(
#     description= 'Click to Select Excel File for Upload:',
#     disabled = False,
#     display = 'flex',
#     style = style,
#     flex_flow = 'column',
#     align_items='stretch',
#     layout = layout
# )

#get user input for program review separated by a comma
input_text_program = widgets.Text(
    description= 'Enter Product Name:',
    disabled = False,
    display = 'flex',
    style = style,
    flex_flow = 'column',
    align_items='stretch',
    layout = layout    
)
output_text_program = widgets.Text()
def bind_input_to_output(sender):
    output_text_program.value = input_text_program.value
# Tell the text input widget to call bind_input_to_output() on submit
input_text_program.on_submit(bind_input_to_output)

#get user input for Acad Level separated by a comma
input_text_listofacad = widgets.Text(
    description= 'Enter Region:',
    disabled = False,
    display = 'flex',
    style = style,
    flex_flow = 'column',
    align_items='stretch',
    layout = layout
)
output_text_listofacad = widgets.Text()
def bind_input_to_output(sender):
    output_text_listofacad.value = input_text_listofacad.value
# Tell the text input widget to call bind_input_to_output() on submit
input_text_listofacad.on_submit(bind_input_to_output)

#get user input for listoftermsA SU/WI separated by a comma
input_text_listoftermsA = widgets.Text(
    description= 'List Fiscal Years sepparated by comma:',
    disabled = False,
    display = 'flex',
    style = style,
    flex_flow = 'column',
    align_items='stretch',
    layout = layout    
)
output_text_listoftermsA = widgets.Text()
def bind_input_to_output(sender):
    output_text_listoftermsA.value = input_text_listoftermsA.value
# Tell the text input widget to call bind_input_to_output() on submit
input_text_listoftermsA.on_submit(bind_input_to_output)

# #run all code function button widget
def run_all(ev):
    display(Javascript('IPython.notebook.execute_cell_range(IPython.notebook.get_selected_index()+1, IPython.notebook.ncells())'))

button = widgets.Button(description="Run Program")
button.on_click(run_all)

# display(upload)
display(input_text_listofacad)
display(input_text_listoftermsA)
display(input_text_program)
display(button)
#hide raw code from end user
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>'''
)
# Out:
# Text(value='', description='Enter Region:', layout=Layout(height='40px', width='auto'), style=DescriptionStyle…
# Text(value='', description='List Fiscal Years sepparated by comma:', layout=Layout(height='40px', width='auto'…
# Text(value='', description='Enter Product Name:', layout=Layout(height='40px', width='auto'), style=Descriptio…
# Button(description='Run Program', style=ButtonStyle())
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>

# %%
# #read in user uploaded Excel File
# with open("input.xlsx", "w+b") as i:
#     i.write(upload.data[0])

# import pandas as pd
# sheets = pd.read_excel(
#     io = 'input.xlsx',
#     inp_file= 'input.xlsx',
#     sheet_name=[
#         "Sheet1",
#     ],
# )

# #create dataframe from user uploaded Excel File
import pandas as pd

url = 'https://raw.githubusercontent.com/RicardoASantos1234/DataSets/main/ConsumerDummyData.csv'
df = pd.read_csv(url)
listofacadlevel = output_text_listofacad.value.split(",")
listoftermsA = output_text_listoftermsA.value.split(",")
ProgRev = output_text_program.value.split(",")

# %%
#######################################################
#import libraries needed and format diplay to show all columns within view
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 10)
pd.options.display.precision = 2
import warnings
warnings.filterwarnings('ignore')
from IPython.display import HTML
from datetime import datetime####################################################
from matplotlib.ticker import FuncFormatter

plt.rcParams
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'


how_many_years_to_create_average = 3
how_many_terms_to_create_average = -2*how_many_years_to_create_average 
#import dataset
df.rename(columns= {'Order ID': 'Number of Records'}, inplace=True)
df2 = df

######################################DO NOT TOUCH################################################################
#FUNCTIONS YOU CAN CALL ON MAKE LIFE EASY

#This function divides one dataframe from the other and returns results
def divide_by_all(df,df2):
    div_all = df/df2
    return div_all

#function to gather selected acad level from given dataframe
def acadlevel_select(df, acadlevel):
    acad_select_data = df[df['Region']== i][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    return acad_select_data

#function to gather selected terms from given dataframe
def term_select(df, term):
    term_select_data = df[df['Fiscal Year']== i][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    return term_select_data

#function to gather selected gender count from given dataframe
def gender_select(df, gender):
    selected_gender = df[df['Consumer Gender']== gender][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    selected_genderR = selected_gender.groupby(['Fiscal Year'])
    selected_genderR1 = selected_genderR['Number of Records'].count()
    selected_genderR1 = pd.DataFrame(selected_genderR1)
    return selected_genderR1

#function to gather selected ethnicity count from selected dataframe
def ethnicity_select(df, ethnicity):
    selected_ethnicity = df[df['Consumer Ethnicity ']==ethnicity][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    selected_ethnicityR = selected_ethnicity.groupby(['Fiscal Year'])
    selected_ethnicityR1 = selected_ethnicityR['Number of Records'].count()
    selected_ethnicityR1 = pd.DataFrame(selected_ethnicityR1)
    return selected_ethnicityR1 

#function to generate count of dataframe by term
def generate_count(df):
    df1 = df.groupby(['Fiscal Year'])
    dfa = df1['Number of Records'].count()
    df_df = pd.DataFrame(dfa)
    return df_df

#function to select actv programs and use this results to create new df with values
def actv_prog_select(df, actv_prog):
    prog_select_data = df[df['Active Programs']== actv_prog][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    return prog_select_data

#function to create dataset from given df from selected school it takes dataframe and school name in ''
def school_select(df, school):
    df = df[df['Product Line']== school][['Fiscal Year','State', 'Consumer Gender', 'Product #', \
                                        'Product Line', 'Region', 'Consumer Ethnicity ', 'First Time Customer', 'Number of Records']]
    return df

### function to rename list of active programs with a new name 
###NOTE for list_actv_prog feed it a list variable example( n = ['ndfidsif', 'isdhfsdfi']) the replacement
### enter it in ''
def rename(df, list_actv_prog, replacement):
    df['Product #']= df['Product #'].replace(list_actv_prog, replacement)
    return df

##function to convert dataframe values to percent
def convert_to_percent(df):
    df['Number of Records'] = df['Number of Records'].astype(float).map("{:.2%}".format)
    return df

def three_year_avg1(df):
    start_avg = df.iloc[how_many_terms_to_create_average:,:]
    three_yr_avg = start_avg.mean()
    return three_yr_avg

#create ac prog dataframe for all that dont need exclusions
def Step2(cleandata, string_to_find, replacement):
    ac_prog_df = cleandata[cleandata['Product #'].str.contains(string_to_find)]
    replacement1 = replacement
    return ac_prog_df, replacement


#calculate reporting
def Step3A(listofterms1, Selected_School, cleandata, replacement1, actv_prog_select1):       

    ac_prog_df = actv_prog_select1
    Selected_School1 = Selected_School
    Selected_School1_label = Selected_School
    actv_prog_select1_label = replacement1
    Selected_School1_label = Selected_School
    term_average_label = 3
    #listoftermsA = listofterms1

    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    pd.set_option('display.max_rows', 50)
    pd.set_option('display.max_columns', 50)
    pd.set_option('display.width', 10)
    pd.options.display.precision = 2
    import warnings
    warnings.filterwarnings('ignore')
    from IPython.display import HTML
    from datetime import datetime####################################################
    from matplotlib.ticker import FuncFormatter

    plt.rcParams
    class bcolors:
        HEADER = '\033[95m'
        OKBLUE = '\033[94m'
        OKGREEN = '\033[92m'
        WARNING = '\033[93m'
        FAIL = '\033[91m'
        ENDC = '\033[0m'
        BOLD = '\033[1m'
        UNDERLINE = '\033[4m'
    def reindex1(df):
        df = df.reindex(listofterms1).fillna(0)
        return df
    actv_prog_select1 = ac_prog_df
    actv_prog_select1_count = reindex1(generate_count(actv_prog_select1))
    actv_prog_select1_count_3yr_avg = three_year_avg1(actv_prog_select1_count)

    actv_prog_select1_F_count = reindex1(gender_select(actv_prog_select1, 'F'))
    actv_prog_select1_F_count_3yr_avg = three_year_avg1(actv_prog_select1_F_count)

    actv_prog_select1_F_div_all = reindex1(divide_by_all(actv_prog_select1_F_count, actv_prog_select1_count))
    actv_prog_select1_F_div_all_3yr_avg = three_year_avg1(actv_prog_select1_F_div_all)
    actv_prog_select1_F_div_all_3yr_avg_percent = format(actv_prog_select1_F_div_all_3yr_avg['Number of Records'], '.2%')
    actv_prog_select1_F_div_all_percent = actv_prog_select1_F_div_all.style.format({'Number of Records': "{:.2%}"})

    actv_prog_select1_M_count = reindex1(gender_select(actv_prog_select1, 'M'))
    actv_prog_select1_M_count_3yr_avg = three_year_avg1(actv_prog_select1_M_count)
    actv_prog_select1_M_div_all = reindex1(divide_by_all(actv_prog_select1_M_count, actv_prog_select1_count))
    actv_prog_select1_M_div_all_3yr_avg = three_year_avg1(actv_prog_select1_M_div_all)
    actv_prog_select1_M_div_all_3yr_avg_percent = format(actv_prog_select1_M_div_all_3yr_avg['Number of Records'], '.2%')
    actv_prog_select1_M_div_all_percent = actv_prog_select1_M_div_all.style.format({'Number of Records': "{:.2%}"})

    actv_prog_select1_AfrAmr_count = reindex1(ethnicity_select(actv_prog_select1, 'Race1'))
    actv_prog_select1_AfrAmr_count_3yr_avg = three_year_avg1(actv_prog_select1_AfrAmr_count)
    actv_prog_select1_AfrAmr_div_all = reindex1(divide_by_all(actv_prog_select1_AfrAmr_count, actv_prog_select1_count))
    actv_prog_select1_AfrAmr_div_all_3yr_avg = three_year_avg1(actv_prog_select1_AfrAmr_div_all)
    actv_prog_select1_AfrAmr_div_all_percent = actv_prog_select1_AfrAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_AfrAmr_div_all_3yr_avg_percent = format(actv_prog_select1_AfrAmr_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_Asn_count = reindex1(ethnicity_select(actv_prog_select1, 'Race2'))
    actv_prog_select1_Asn_count_3yr_avg = three_year_avg1(actv_prog_select1_Asn_count)
    actv_prog_select1_Asn_div_all = reindex1(divide_by_all(actv_prog_select1_Asn_count, actv_prog_select1_count))
    actv_prog_select1_Asn_div_all_3yr_avg = three_year_avg1(actv_prog_select1_Asn_div_all)
    actv_prog_select1_Asn_div_all_percent = actv_prog_select1_Asn_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_Asn_div_all_3yr_avg_percent = format(actv_prog_select1_Asn_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_Hisp_count = reindex1(ethnicity_select(actv_prog_select1, 'Race3'))
    actv_prog_select1_Hisp_count_3yr_avg = three_year_avg1(actv_prog_select1_Hisp_count)
    actv_prog_select1_Hisp_div_all = reindex1(divide_by_all(actv_prog_select1_Hisp_count, actv_prog_select1_count))
    actv_prog_select1_Hisp_div_all_3yr_avg = three_year_avg1(actv_prog_select1_Hisp_div_all)
    actv_prog_select1_Hisp_div_all_percent = actv_prog_select1_Hisp_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_Hisp_div_all_3yr_avg_percent = format(actv_prog_select1_Hisp_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_Int_count = reindex1(ethnicity_select(actv_prog_select1, 'Race4'))
    actv_prog_select1_Int_count_3yr_avg = three_year_avg1(actv_prog_select1_Int_count)
    actv_prog_select1_Int_div_all = reindex1(divide_by_all(actv_prog_select1_Int_count, actv_prog_select1_count))
    actv_prog_select1_Int_div_all_3yr_avg = three_year_avg1(actv_prog_select1_Int_div_all)
    actv_prog_select1_Int_div_all_percent = actv_prog_select1_Int_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_Int_div_all_3yr_avg_percent = format(actv_prog_select1_Int_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_PcfIsl_count = reindex1(ethnicity_select(actv_prog_select1, 'Race7'))
    actv_prog_select1_PcfIsl_count_3yr_avg = three_year_avg1(actv_prog_select1_PcfIsl_count)
    actv_prog_select1_PcfIsl_div_all = reindex1(divide_by_all(actv_prog_select1_PcfIsl_count, actv_prog_select1_count))
    actv_prog_select1_PcfIsl_div_all_3yr_avg = three_year_avg1(actv_prog_select1_PcfIsl_div_all)
    actv_prog_select1_PcfIsl_div_all_percent = actv_prog_select1_PcfIsl_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_PcfIsl_div_all_3yr_avg_percent = format(actv_prog_select1_PcfIsl_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_Ukn_count = reindex1(ethnicity_select(actv_prog_select1, 'Race5'))
    actv_prog_select1_Ukn_count_3yr_avg = three_year_avg1(actv_prog_select1_Ukn_count)
    actv_prog_select1_Ukn_div_all = reindex1(divide_by_all(actv_prog_select1_Ukn_count, actv_prog_select1_count))
    actv_prog_select1_Ukn_div_all_3yr_avg = three_year_avg1(actv_prog_select1_Ukn_div_all)
    actv_prog_select1_Ukn_div_all_percent = actv_prog_select1_Ukn_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_Ukn_div_all_3yr_avg_percent = format(actv_prog_select1_Ukn_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_Wht_count = reindex1(ethnicity_select(actv_prog_select1, 'Race6'))
    actv_prog_select1_Wht_count_3yr_avg = three_year_avg1(actv_prog_select1_Wht_count)
    actv_prog_select1_Wht_div_all = reindex1(divide_by_all(actv_prog_select1_Wht_count, actv_prog_select1_count))
    actv_prog_select1_Wht_div_all_3yr_avg = three_year_avg1(actv_prog_select1_Wht_div_all)
    actv_prog_select1_Wht_div_all_percent = actv_prog_select1_Wht_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_Wht_div_all_3yr_avg_percent = format(actv_prog_select1_Wht_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_NtvAmr_count = reindex1(ethnicity_select(actv_prog_select1, 'Race8'))
    actv_prog_select1_NtvAmr_count_3yr_avg = three_year_avg1(actv_prog_select1_NtvAmr_count)
    actv_prog_select1_NtvAmr_div_all = reindex1(divide_by_all(actv_prog_select1_NtvAmr_count, actv_prog_select1_count))
    actv_prog_select1_NtvAmr_div_all_3yr_avg = three_year_avg1(actv_prog_select1_NtvAmr_div_all)
    actv_prog_select1_NtvAmr_div_all_percent = actv_prog_select1_NtvAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_NtvAmr_div_all_3yr_avg_percent = format(actv_prog_select1_NtvAmr_div_all_3yr_avg['Number of Records'], '.2%')

    actv_prog_select1_UREM_count = actv_prog_select1_AfrAmr_count + actv_prog_select1_NtvAmr_count + actv_prog_select1_Hisp_count\
                                    + actv_prog_select1_PcfIsl_count
    actv_prog_select1_UREM_count_3yr_avg = three_year_avg1(actv_prog_select1_UREM_count)
    actv_prog_select1_UREM_div_all = reindex1(divide_by_all(actv_prog_select1_UREM_count, actv_prog_select1_count))
    actv_prog_select1_UREM_div_all_3yr_avg = three_year_avg1(actv_prog_select1_UREM_div_all)
    actv_prog_select1_UREM_div_all_percent = actv_prog_select1_UREM_div_all.style.format({'Number of Records': "{:.2%}"})
    actv_prog_select1_UREM_div_all_3yr_avg_percent = format(actv_prog_select1_UREM_div_all_3yr_avg['Number of Records'], '.2%')

    ######################################DO NOT TOUCH################################################################
    Selected_School1 = school_select(cleandata, Selected_School1)
    Selected_School1_count = reindex1(generate_count(Selected_School1))
    Selected_School1_div_actv_prog = reindex1(divide_by_all(actv_prog_select1_count, Selected_School1_count))
    Selected_School1_div_actv_prog_3yr_avg = three_year_avg1(Selected_School1_div_actv_prog)
    Selected_School1_div_actv_prog_percent = Selected_School1_div_actv_prog.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_div_actv_prog_3yr_avg_percent = format(Selected_School1_div_actv_prog_3yr_avg['Number of Records'], '.2%')

    Selected_School1_count_3yr_avg = three_year_avg1(Selected_School1_count)
    Selected_School1_F_count = reindex1(gender_select(Selected_School1, 'F'))
    Selected_School1_F_count_3yr_avg = three_year_avg1(Selected_School1_F_count)
    Selected_School1_F_div_all = reindex1(divide_by_all(Selected_School1_F_count, Selected_School1_count))
    Selected_School1_F_div_all_3yr_avg = three_year_avg1(Selected_School1_F_div_all)
    Selected_School1_M_count = reindex1(gender_select(Selected_School1, 'M'))
    Selected_School1_M_count_3yr_avg = three_year_avg1(Selected_School1_M_count)
    Selected_School1_M_div_all = reindex1(divide_by_all(Selected_School1_M_count, Selected_School1_count))
    Selected_School1_M_div_all_3yr_avg = three_year_avg1(Selected_School1_M_div_all)
    Selected_School1_AfrAmr_count = reindex1(ethnicity_select(Selected_School1, 'Race1'))
    Selected_School1_AfrAmr_count_3yr_avg = three_year_avg1(Selected_School1_AfrAmr_count)
    Selected_School1_AfrAmr_div_all = reindex1(divide_by_all(Selected_School1_AfrAmr_count, Selected_School1_count))
    Selected_School1_AfrAmr_div_all_3yr_avg = three_year_avg1(Selected_School1_AfrAmr_div_all)
    Selected_School1_Asn_count = reindex1(ethnicity_select(Selected_School1, 'Race2'))
    Selected_School1_Asn_count_3yr_avg = three_year_avg1(Selected_School1_Asn_count)
    Selected_School1_Asn_div_all = reindex1(divide_by_all(Selected_School1_Asn_count, Selected_School1_count))
    Selected_School1_Asn_div_all_3yr_avg = three_year_avg1(Selected_School1_Asn_div_all)
    Selected_School1_Wht_count = reindex1(ethnicity_select(Selected_School1, 'Race6'))
    Selected_School1_Wht_count_3yr_avg = three_year_avg1(Selected_School1_Wht_count)
    Selected_School1_Wht_div_all = reindex1(divide_by_all(Selected_School1_Wht_count, Selected_School1_count))
    Selected_School1_Wht_div_all_3yr_avg = three_year_avg1(Selected_School1_Wht_div_all)
    Selected_School1_NtvAmr_count = reindex1(ethnicity_select(Selected_School1, 'Race8'))
    Selected_School1_NtvAmr_count_3yr_avg = three_year_avg1(Selected_School1_NtvAmr_count)
    Selected_School1_NtvAmr_div_all = reindex1(divide_by_all(Selected_School1_NtvAmr_count, Selected_School1_count))
    Selected_School1_NtvAmr_div_all_3yr_avg = three_year_avg1(Selected_School1_NtvAmr_div_all)
    Selected_School1_Int_count = reindex1(ethnicity_select(Selected_School1, 'Race4'))
    Selected_School1_Int_count_3yr_avg = three_year_avg1(Selected_School1_Int_count)
    Selected_School1_Int_div_all = reindex1(divide_by_all(Selected_School1_Int_count, Selected_School1_count))
    Selected_School1_Int_div_all_3yr_avg = three_year_avg1(Selected_School1_Int_div_all)
    Selected_School1_Ukn_count = reindex1(ethnicity_select(Selected_School1, 'Race5'))
    Selected_School1_Ukn_count_3yr_avg = three_year_avg1(Selected_School1_Ukn_count)
    Selected_School1_Ukn_div_all = reindex1(divide_by_all(Selected_School1_Ukn_count, Selected_School1_count))
    Selected_School1_Ukn_div_all_3yr_avg = three_year_avg1(Selected_School1_Ukn_div_all)
    Selected_School1_PcfIsl_count = reindex1(ethnicity_select(Selected_School1, 'Race7'))
    Selected_School1_PcfIsl_count_3yr_avg = three_year_avg1(Selected_School1_PcfIsl_count)
    Selected_School1_PcfIsl_div_all = reindex1(divide_by_all(Selected_School1_PcfIsl_count, Selected_School1_count))
    Selected_School1_PcfIsl_div_all_3yr_avg = three_year_avg1(Selected_School1_PcfIsl_div_all)
    Selected_School1_Hisp_count = reindex1(ethnicity_select(Selected_School1, 'Race3'))
    Selected_School1_Hisp_count_3yr_avg = three_year_avg1(Selected_School1_Hisp_count)
    Selected_School1_Hisp_div_all = reindex1(divide_by_all(Selected_School1_Hisp_count, Selected_School1_count))
    Selected_School1_Hisp_div_all_3yr_avg = three_year_avg1(Selected_School1_Hisp_div_all)
    Selected_School1_UREM_count = Selected_School1_AfrAmr_count + Selected_School1_NtvAmr_count + Selected_School1_PcfIsl_count\
                                                              + Selected_School1_Hisp_count
    Selected_School1_UREM_count_3yr_avg = three_year_avg1(Selected_School1_UREM_count ) 
    Selected_School1_UREM_div_all = reindex1(divide_by_all(Selected_School1_UREM_count, Selected_School1_count))
    Selected_School1_UREM_div_all_3yr_avg = three_year_avg1(Selected_School1_UREM_div_all)

    Selected_School1_F_div_all_3yr_avg_percent = format(Selected_School1_F_div_all_3yr_avg['Number of Records'], '.2%')
    Selected_School1_F_div_all_percent = Selected_School1_F_div_all.style.format({'Number of Records': "{:.2%}"})

    Selected_School1_M_div_all_3yr_avg_percent = format(Selected_School1_M_div_all_3yr_avg['Number of Records'], '.2%')
    Selected_School1_M_div_all_percent = Selected_School1_M_div_all.style.format({'Number of Records': "{:.2%}"})

    Selected_School1_AfrAmr_div_all_percent = Selected_School1_AfrAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_AfrAmr_div_all_3yr_avg_percent = format(Selected_School1_AfrAmr_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_Asn_div_all_percent = Selected_School1_Asn_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_Asn_div_all_3yr_avg_percent = format(Selected_School1_Asn_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_Hisp_div_all_percent = Selected_School1_Hisp_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_Hisp_div_all_3yr_avg_percent = format(Selected_School1_Hisp_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_Int_div_all_percent = Selected_School1_Int_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_Int_div_all_3yr_avg_percent = format(Selected_School1_Int_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_PcfIsl_div_all_percent = Selected_School1_PcfIsl_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_PcfIsl_div_all_3yr_avg_percent = format(Selected_School1_PcfIsl_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_Ukn_div_all_percent = Selected_School1_Ukn_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_Ukn_div_all_3yr_avg_percent = format(Selected_School1_Ukn_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_Wht_div_all_percent = Selected_School1_Wht_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_Wht_div_all_3yr_avg_percent = format(Selected_School1_Wht_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_NtvAmr_div_all_percent = Selected_School1_NtvAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_NtvAmr_div_all_3yr_avg_percent = format(Selected_School1_NtvAmr_div_all_3yr_avg['Number of Records'], '.2%')

    Selected_School1_UREM_div_all_percent = Selected_School1_UREM_div_all.style.format({'Number of Records': "{:.2%}"})
    Selected_School1_UREM_div_all_3yr_avg_percent = format(Selected_School1_UREM_div_all_3yr_avg['Number of Records'], '.2%')
    ######################################DO NOT TOUCH################################################################
    #find count and percentages as well as three year average for Brand for the following:
    #actv prog, female, male, ethnicities(AfrAmr, Asn, Hisp, Int, Unkn, Wht, NtvAmr, PcfIsl, UREM)
    Brand_Count_by_term = reindex1(generate_count(cleandata))
    Brand_Count_by_term_div_actv_prog = reindex1(divide_by_all(actv_prog_select1_count, Brand_Count_by_term))
    Brand_Count_by_term_div_actv_prog_3yr_avg = three_year_avg1(Brand_Count_by_term_div_actv_prog)
    Brand_Count_by_term_div_actv_prog_percent = Brand_Count_by_term_div_actv_prog.style.format({'Number of Records': "{:.2%}"})
    Brand_Count_by_term_div_actv_prog_3yr_avg_percent = format(Brand_Count_by_term_div_actv_prog_3yr_avg ['Number of Records'], '.2%') 

    Brand_Count_by_term_3yr_avg = three_year_avg1(Brand_Count_by_term)
    Brand_Count_F = reindex1(gender_select(cleandata, 'F'))
    Brand_Count_F_3yr_avg = three_year_avg1(Brand_Count_F)
    Brand_Count_F_div_all = reindex1(divide_by_all(Brand_Count_F, Brand_Count_by_term))
    Brand_Count_F_div_all_3yr_avg = three_year_avg1(Brand_Count_F_div_all)
    Brand_Count_M = reindex1(gender_select(cleandata, 'M'))
    Brand_Count_M_3yr_avg = three_year_avg1(Brand_Count_M)
    Brand_Count_M_div_all = reindex1(divide_by_all(Brand_Count_M, Brand_Count_by_term))
    Brand_Count_M_div_all_3yr_avg = three_year_avg1(Brand_Count_M_div_all)
    Brand_AfrAmr_count = reindex1(ethnicity_select(cleandata, 'Race1'))
    Brand_AfrAmr_count_3yr_avg = three_year_avg1(Brand_AfrAmr_count)
    Brand_AfrAmr_div_all = reindex1(divide_by_all(Brand_AfrAmr_count, Brand_Count_by_term))
    Brand_AfrAmr_div_all_3yr_avg = three_year_avg1(Brand_AfrAmr_div_all)
    Brand_Asn_count = reindex1(ethnicity_select(cleandata, 'Race2'))
    Brand_Asn_count_3yr_avg = three_year_avg1(Brand_Asn_count)
    Brand_Asn_div_all = reindex1(divide_by_all(Brand_Asn_count, Brand_Count_by_term))
    Brand_Asn_div_all_3yr_avg = three_year_avg1(Brand_Asn_div_all)
    Brand_Wht_count = reindex1(ethnicity_select(cleandata, 'Race6'))
    Brand_Wht_count_3yr_avg = three_year_avg1(Brand_Wht_count)
    Brand_Wht_div_all = reindex1(divide_by_all(Brand_Wht_count, Brand_Count_by_term))
    Brand_Wht_div_all_3yr_avg = three_year_avg1(Brand_Wht_div_all)
    Brand_Ukn_count = reindex1(ethnicity_select(cleandata, 'Race5'))
    Brand_Ukn_count_3yr_avg = three_year_avg1(Brand_Ukn_count)
    Brand_Ukn_div_all = reindex1(divide_by_all(Brand_Ukn_count, Brand_Count_by_term))
    Brand_Ukn_div_all_3yr_avg = three_year_avg1(Brand_Ukn_div_all)
    Brand_PcfIsl_count = reindex1(ethnicity_select(cleandata, 'Race7'))
    Brand_PcfIsl_count_3yr_avg = three_year_avg1(Brand_PcfIsl_count)
    Brand_PcfIsl_div_all = reindex1(divide_by_all(Brand_PcfIsl_count, Brand_Count_by_term))
    Brand_PcfIsl_div_all_3yr_avg = three_year_avg1(Brand_PcfIsl_div_all)
    Brand_NtvAmr_count = reindex1(ethnicity_select(cleandata, 'Race8'))
    Brand_NtvAmr_count_3yr_avg = three_year_avg1(Brand_NtvAmr_count)
    Brand_NtvAmr_div_all = reindex1(divide_by_all(Brand_NtvAmr_count, Brand_Count_by_term))
    Brand_NtvAmr_div_all_3yr_avg = three_year_avg1(Brand_NtvAmr_div_all)
    Brand_Int_count = reindex1(ethnicity_select(cleandata, 'Race4'))
    Brand_Int_count_3yr_avg = three_year_avg1(Brand_Int_count)
    Brand_Int_div_all = reindex1(divide_by_all(Brand_Int_count, Brand_Count_by_term))
    Brand_Int_div_all_3yr_avg = three_year_avg1(Brand_Int_div_all)
    Brand_Hisp_count = reindex1(ethnicity_select(cleandata, 'Race3'))
    Brand_Hisp_count_3yr_avg = three_year_avg1(Brand_Hisp_count)
    Brand_Hisp_div_all = reindex1(divide_by_all(Brand_Hisp_count, Brand_Count_by_term))
    Brand_Hisp_div_all_3yr_avg = three_year_avg1(Brand_Hisp_div_all)
    Brand_UREM_count = Brand_AfrAmr_count + Brand_NtvAmr_count + Brand_Hisp_count\
                                    + Brand_PcfIsl_count
    Brand_UREM_count_3yr_avg = three_year_avg1(Brand_UREM_count)
    Brand_UREM_div_all = reindex1(divide_by_all(Brand_UREM_count, Brand_Count_by_term))
    Brand_UREM_div_all_3yr_avg = three_year_avg1(Brand_UREM_div_all)

    Brand_Count_M_div_all_3yr_avg_percent = format(Brand_Count_M_div_all_3yr_avg['Number of Records'], '.2%')
    Brand_Count_M_div_all_percent = Brand_Count_M_div_all.style.format({'Number of Records': "{:.2%}"})

    Brand_Count_F_div_all_3yr_avg_percent = format(Brand_Count_F_div_all_3yr_avg['Number of Records'], '.2%')
    Brand_Count_F_div_all_percent = Brand_Count_F_div_all.style.format({'Number of Records': "{:.2%}"})

    Brand_AfrAmr_div_all_percent = Brand_AfrAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_AfrAmr_div_all_3yr_avg_percent = format(Brand_AfrAmr_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_Asn_div_all_percent = Brand_Asn_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_Asn_div_all_3yr_avg_percent = format(Brand_Asn_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_Hisp_div_all_percent = Brand_Hisp_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_Hisp_div_all_3yr_avg_percent = format(Brand_Hisp_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_Int_div_all_percent = Brand_Int_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_Int_div_all_3yr_avg_percent = format(Brand_Int_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_PcfIsl_div_all_percent = Brand_PcfIsl_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_PcfIsl_div_all_3yr_avg_percent = format(Brand_PcfIsl_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_Ukn_div_all_percent = Brand_Ukn_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_Ukn_div_all_3yr_avg_percent = format(Brand_Ukn_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_Wht_div_all_percent = Brand_Wht_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_Wht_div_all_3yr_avg_percent = format(Brand_Wht_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_NtvAmr_div_all_percent = Brand_NtvAmr_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_NtvAmr_div_all_3yr_avg_percent = format(Brand_NtvAmr_div_all_3yr_avg['Number of Records'], '.2%')

    Brand_UREM_div_all_percent = Brand_UREM_div_all.style.format({'Number of Records': "{:.2%}"})
    Brand_UREM_div_all_3yr_avg_percent = format(Brand_UREM_div_all_3yr_avg['Number of Records'], '.2%')
    ##################################################################################################################
    Graduate_Program_Count_Percentages = pd.DataFrame()
    selected_school_p = Selected_School1_div_actv_prog.transpose()
    selected_school_p[''+str(term_average_label)+ ' Year Average'] = Selected_School1_div_actv_prog_3yr_avg
    selected_school_p.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Percent. '}, inplace = True)
    selected_school_p = (selected_school_p * 100).round(1).astype(str) + '%'

    Brand_p = Brand_Count_by_term_div_actv_prog.transpose()
    Brand_p[''+str(term_average_label)+ ' Year Average'] = Brand_Count_by_term_div_actv_prog_3yr_avg
    Brand_p.rename(index = {'Number of Records': 'Brand Percent. '}, inplace = True)
    Brand_p = (Brand_p * 100).round(1).astype(str) + '%'

    Graduate_Program_Count_Percentages = Graduate_Program_Count_Percentages.append(selected_school_p)
    Graduate_Program_Count_Percentages = Graduate_Program_Count_Percentages.append(Brand_p)
    Graduate_Program_Count_Percentages

    ########## THIS BLOCK OF CODE GENERATES A DATAFRAME FOR THE PERCENT OF ACTV PROG1, SELECTED SCHOOL1, Brand BY TERM/GENDER
    Gender_Graduate_Program_Count_Percentages = pd.DataFrame()
    act_prog_gender_percentages = pd.DataFrame()
    act_prog_f = actv_prog_select1_F_div_all.transpose()
    act_prog_f[''+str(term_average_label)+ ' Year Average']= actv_prog_select1_F_div_all_3yr_avg
    act_prog_f.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Female Percent. '}, inplace = True)
    act_prog_f = (act_prog_f*100).round(1).astype(str) + '%'

    act_prog_m = actv_prog_select1_M_div_all.transpose()
    act_prog_m[''+str(term_average_label)+ ' Year Average']= actv_prog_select1_M_div_all_3yr_avg
    act_prog_m.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Male Percent.'}, inplace = True)
    act_prog_m = (act_prog_m*100).round(1).astype(str) + '%'

    act_prog_gender_percentages = act_prog_gender_percentages.append(act_prog_m)
    act_prog_gender_percentages = act_prog_gender_percentages.append(act_prog_f)

    #actv Ethnicity
    act_prog_ethnicity_percentages = pd.DataFrame()
    act_prog_afr = actv_prog_select1_AfrAmr_div_all.transpose()
    act_prog_afr[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_AfrAmr_div_all_3yr_avg
    act_prog_afr.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race1 Percent.'}, inplace = True)
    act_prog_afr = (act_prog_afr*100).round(1).astype(str) + '%'

    act_prog_ntv = actv_prog_select1_NtvAmr_div_all.transpose()
    act_prog_ntv[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_NtvAmr_div_all_3yr_avg
    act_prog_ntv.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race8 Percent.'}, inplace = True)
    act_prog_ntv = (act_prog_ntv*100).round(1).astype(str) + '%'

    act_prog_asn = actv_prog_select1_Asn_div_all.transpose()
    act_prog_asn[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Asn_div_all_3yr_avg
    act_prog_asn.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race2 Percent.'}, inplace = True)
    act_prog_asn = (act_prog_asn*100).round(1).astype(str) + '%'

    act_prog_pcf = actv_prog_select1_PcfIsl_div_all.transpose()
    act_prog_pcf[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_PcfIsl_div_all_3yr_avg
    act_prog_pcf.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Pacifc Islander Percent.'}, inplace = True)
    act_prog_pcf = (act_prog_pcf*100).round(1).astype(str) + '%'

    act_prog_his = actv_prog_select1_Hisp_div_all.transpose()
    act_prog_his[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Hisp_div_all_3yr_avg
    act_prog_his.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race3 Percent.'}, inplace = True)
    act_prog_his = (act_prog_his*100).round(1).astype(str) + '%'

    act_prog_wht = actv_prog_select1_Wht_div_all.transpose()
    act_prog_wht[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Wht_div_all_3yr_avg
    act_prog_wht.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race6 Percent.'}, inplace = True)
    act_prog_wht = (act_prog_wht*100).round(1).astype(str) + '%'

    act_prog_int = actv_prog_select1_Int_div_all.transpose()
    act_prog_int[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Int_div_all_3yr_avg
    act_prog_int.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Race4 Percent.'}, inplace = True)
    act_prog_int = (act_prog_int*100).round(1).astype(str) + '%'

    act_prog_ukn = actv_prog_select1_Ukn_div_all.transpose()
    act_prog_ukn[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Ukn_div_all_3yr_avg
    act_prog_ukn.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Declined to State Percent.'}, inplace = True)
    act_prog_ukn = (act_prog_ukn*100).round(1).astype(str) + '%'

    act_prog_urem = actv_prog_select1_UREM_div_all.transpose()
    act_prog_urem[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_UREM_div_all_3yr_avg
    act_prog_urem.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' UREM Percent.'}, inplace = True)
    act_prog_urem = (act_prog_urem*100).round(1).astype(str) + '%'

    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_afr)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_ntv)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_asn)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_pcf)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_his)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_wht)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_int)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_ukn)
    act_prog_ethnicity_percentages = act_prog_ethnicity_percentages.append(act_prog_urem)

    #SCHOOL
    selected_school_gender_percentages = pd.DataFrame()
    sel_scho_f = Selected_School1_F_div_all.transpose()
    sel_scho_f[''+str(term_average_label)+ ' Year Average'] = Selected_School1_F_div_all_3yr_avg
    sel_scho_f.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Female Percent.'}, inplace = True)
    sel_scho_f = (sel_scho_f*100).round(1).astype(str) + '%'

    sel_scho_m = Selected_School1_M_div_all.transpose()
    sel_scho_m[''+str(term_average_label)+ ' Year Average']= Selected_School1_M_div_all_3yr_avg
    sel_scho_m.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Male Percent.'}, inplace = True)
    sel_scho_m = (sel_scho_m*100).round(1).astype(str) + '%'

    selected_school_gender_percentages = selected_school_gender_percentages.append(sel_scho_m)
    selected_school_gender_percentages = selected_school_gender_percentages.append(sel_scho_f)

    Selected_School1_ethnicity_percentages = pd.DataFrame()
    Selected_School1_afr = Selected_School1_AfrAmr_div_all.transpose()
    Selected_School1_afr[''+str(term_average_label)+ ' Year Average'] = Selected_School1_AfrAmr_div_all_3yr_avg
    Selected_School1_afr.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race1 Percent.'}, inplace = True)
    Selected_School1_afr = (Selected_School1_afr*100).round(1).astype(str) + '%'

    Selected_School1_ntv = Selected_School1_NtvAmr_div_all.transpose()
    Selected_School1_ntv[''+str(term_average_label)+ ' Year Average'] = Selected_School1_NtvAmr_div_all_3yr_avg
    Selected_School1_ntv.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race8 Percent.'}, inplace = True)
    Selected_School1_ntv = (Selected_School1_ntv*100).round(1).astype(str) + '%'

    Selected_School1_asn = Selected_School1_Asn_div_all.transpose()
    Selected_School1_asn[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Asn_div_all_3yr_avg
    Selected_School1_asn.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race2 Percent.'}, inplace = True)
    Selected_School1_asn = (Selected_School1_asn*100).round(1).astype(str) + '%'

    Selected_School1_pcf = Selected_School1_PcfIsl_div_all.transpose()
    Selected_School1_pcf[''+str(term_average_label)+ ' Year Average'] = Selected_School1_PcfIsl_div_all_3yr_avg
    Selected_School1_pcf.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Pacifc Islander Percent.'}, inplace = True)
    Selected_School1_pcf = (Selected_School1_pcf*100).round(1).astype(str) + '%'

    Selected_School1_his = Selected_School1_Hisp_div_all.transpose()
    Selected_School1_his[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Hisp_div_all_3yr_avg
    Selected_School1_his.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race3 Percent.'}, inplace = True)
    Selected_School1_his = (Selected_School1_his*100).round(1).astype(str) + '%'

    Selected_School1_wht = Selected_School1_Wht_div_all.transpose()
    Selected_School1_wht[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Wht_div_all_3yr_avg
    Selected_School1_wht.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race6 Percent.'}, inplace = True)
    Selected_School1_wht = (Selected_School1_wht*100).round(1).astype(str) + '%'

    Selected_School1_int = Selected_School1_Int_div_all.transpose()
    Selected_School1_int[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Int_div_all_3yr_avg
    Selected_School1_int.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Race4 Percent.'}, inplace = True)
    Selected_School1_int = (Selected_School1_int*100).round(1).astype(str) + '%'

    Selected_School1_ukn = Selected_School1_Ukn_div_all.transpose()
    Selected_School1_ukn[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Ukn_div_all_3yr_avg
    Selected_School1_ukn.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Declined to State Percent.'}, inplace = True)
    Selected_School1_ukn = (Selected_School1_ukn*100).round(1).astype(str) + '%'

    Selected_School1_urem = Selected_School1_UREM_div_all.transpose()
    Selected_School1_urem[''+str(term_average_label)+ ' Year Average'] = Selected_School1_UREM_div_all_3yr_avg
    Selected_School1_urem.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' UREM Percent.'}, inplace = True)
    Selected_School1_urem = (Selected_School1_urem*100).round(1).astype(str) + '%'

    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_afr)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_ntv)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_asn)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_pcf)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_his)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_wht)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_int)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_ukn)
    Selected_School1_ethnicity_percentages = Selected_School1_ethnicity_percentages.append(Selected_School1_urem)

    #Brand
    Brand_gender_percentages = pd.DataFrame()
    Brand_f = Brand_Count_F_div_all.transpose()
    Brand_f[''+str(term_average_label)+ ' Year Average'] = Brand_Count_F_div_all_3yr_avg
    Brand_f.rename(index = {'Number of Records': 'Brand Female Percent.'}, inplace = True)
    Brand_f = (Brand_f*100).round(1).astype(str) + '%'

    Brand_m = Brand_Count_M_div_all.transpose()
    Brand_m[''+str(term_average_label)+ ' Year Average'] = Brand_Count_M_div_all_3yr_avg
    Brand_m.rename(index = {'Number of Records': 'Brand Male Percent.'}, inplace = True)
    Brand_m = (Brand_m*100).round(1).astype(str) + '%'

    Brand_gender_percentages = Brand_gender_percentages.append(Brand_m)
    Brand_gender_percentages = Brand_gender_percentages.append(Brand_f)

    Brand_ethnicity_percentages = pd.DataFrame()
    Brand_afr = Brand_AfrAmr_div_all.transpose()
    Brand_afr[''+str(term_average_label)+ ' Year Average'] = Brand_AfrAmr_div_all_3yr_avg
    Brand_afr.rename(index = {'Number of Records': 'Brand Race1 Percent.'}, inplace = True)
    Brand_afr = (Brand_afr*100).round(1).astype(str) + '%'

    Brand_ntv = Brand_NtvAmr_div_all.transpose()
    Brand_ntv[''+str(term_average_label)+ ' Year Average'] = Brand_NtvAmr_div_all_3yr_avg
    Brand_ntv.rename(index = {'Number of Records': 'Brand Race8 Percent.'}, inplace = True)
    Brand_ntv = (Brand_ntv*100).round(1).astype(str) + '%'

    Brand_asn = Brand_Asn_div_all.transpose()
    Brand_asn[''+str(term_average_label)+ ' Year Average'] = Brand_Asn_div_all_3yr_avg
    Brand_asn.rename(index = {'Number of Records': 'Brand Race2 Percent.'}, inplace = True)
    Brand_asn = (Brand_asn*100).round(1).astype(str) + '%'

    Brand_his = Brand_Hisp_div_all.transpose()
    Brand_his[''+str(term_average_label)+ ' Year Average'] = Brand_Hisp_div_all_3yr_avg
    Brand_his.rename(index = {'Number of Records': 'Brand Race3 Percent.'}, inplace = True)
    Brand_his = (Brand_his*100).round(1).astype(str) + '%'

    Brand_wht = Brand_Wht_div_all.transpose()
    Brand_wht[''+str(term_average_label)+ ' Year Average'] = Brand_Wht_div_all_3yr_avg
    Brand_wht.rename(index = {'Number of Records': 'Brand Race6 Percent.'}, inplace = True)
    Brand_wht = (Brand_wht*100).round(1).astype(str) + '%'

    Brand_int = Brand_Int_div_all.transpose()
    Brand_int[''+str(term_average_label)+ ' Year Average'] = Brand_Int_div_all_3yr_avg
    Brand_int.rename(index = {'Number of Records': 'Brand Race4 Percent.'}, inplace = True)
    Brand_int = (Brand_int*100).round(1).astype(str) + '%'

    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_afr)
    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_ntv)
    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_asn)
    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_his)
    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_wht)
    Brand_ethnicity_percentages = Brand_ethnicity_percentages.append(Brand_int)

    UREM_percentages = pd.DataFrame()
    UREM_percentages = UREM_percentages.append(act_prog_urem)
    UREM_percentages = UREM_percentages.append(Selected_School1_urem)

    ######################################DO NOT TOUCH################################################################
    ####THIS BLOCK OF CELL GENERATES A DATAFRAME FOR THE COUNT FOR ACTV PROG1, SELECTED SCHOOL1, Brand BY TERM
    Graduate_Program_Count = pd.DataFrame()

    actv_prog_select1_count1 = actv_prog_select1_count
    actv_prog_select1_count1 = actv_prog_select1_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog_ = actv_prog_select1_count1.transpose()
    actv_prog_[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_count_3yr_avg
    actv_prog_.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+ ' Count. '}, inplace = True)

    Selected_School1_count1 = Selected_School1_count
    Selected_School1_count1 = Selected_School1_count1.astype(str).replace('\.0', '', regex=True)
    select_school1_ = Selected_School1_count1.transpose()
    select_school1_[''+str(term_average_label)+ ' Year Average'] = Selected_School1_count_3yr_avg
    select_school1_.rename(index = {'Number of Records': ''+str(Selected_School1_label)+ ' Count.'}, inplace = True)

    Brand_Count_by_term1 = Brand_Count_by_term
    Brand_Count_by_term1 = Brand_Count_by_term1.astype(str).replace('\.0', '', regex=True)
    Brand_ = Brand_Count_by_term1.transpose()
    Brand_[''+str(term_average_label)+ ' Year Average'] = Brand_Count_by_term_3yr_avg
    Brand_.rename(index = {'Number of Records': 'Brand Count.'}, inplace = True)

    Graduate_Program_Count = Graduate_Program_Count.append(select_school1_)
    Graduate_Program_Count = Graduate_Program_Count.append(Brand_)

    ##this block of cell generates a dataframe for the gender count of Actv Prog Select1 Chicken (M, F) and three year average
    actv_prog1_gendercount = pd.DataFrame()
    actv_prog_select1_F_count1 = actv_prog_select1_F_count
    actv_prog_select1_F_count1 = actv_prog_select1_F_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_F = actv_prog_select1_F_count1.transpose()
    actv_prog1_F[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_F_count_3yr_avg
    actv_prog1_F.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+' Female Count.'}, inplace = True)

    actv_prog_select1_M_count1 = actv_prog_select1_M_count
    actv_prog_select1_M_count1 = actv_prog_select1_M_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_M = actv_prog_select1_M_count1.transpose()
    actv_prog1_M[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_M_count_3yr_avg
    actv_prog1_M.rename(index = {'Number of Records': ''+str(actv_prog_select1_label)+' Male Count.'}, inplace = True)

    actv_prog1_gendercount = actv_prog1_gendercount.append(actv_prog1_F)
    actv_prog1_gendercount = actv_prog1_gendercount.append(actv_prog1_M)

    ##this block of cell generates a dataframe for the gender count of Selected School1 Chicken (M, F) and three year average
    Selected_School1_gendercount = pd.DataFrame()
    Selected_School1_F_count1 = Selected_School1_F_count
    Selected_School1_F_count1 = Selected_School1_F_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_F = Selected_School1_F_count1.transpose()
    Selected_School1_F[''+str(term_average_label)+ ' Year Average'] = Selected_School1_F_count_3yr_avg
    Selected_School1_F.rename(index = {'Number of Records': ''+str(Selected_School1_label)+' Female Count.'}, inplace = True)

    Selected_School1_M_count1 = Selected_School1_M_count
    Selected_School1_M_count1 = Selected_School1_M_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_M = Selected_School1_M_count1.transpose()
    Selected_School1_M[''+str(term_average_label)+ ' Year Average'] = Selected_School1_M_count_3yr_avg
    Selected_School1_M.rename(index = {'Number of Records': ''+str(Selected_School1_label)+' Male Count.'}, inplace = True)

    Selected_School1_gendercount = Selected_School1_gendercount.append(Selected_School1_F)
    Selected_School1_gendercount = Selected_School1_gendercount.append(Selected_School1_M)

    ##this block of cell generates a dataframe for the gender count of Brand Chicken (M, F) and three year average
    Brand_gendercount = pd.DataFrame()
    Brand_Count_F1 = Brand_Count_F
    Brand_Count_F1  = Brand_Count_F1.astype(str).replace('\.0', '', regex=True)
    Brand_F = Brand_Count_F1 .transpose()
    Brand_F[''+str(term_average_label)+ ' Year Average'] = Brand_Count_F_3yr_avg
    Brand_F.rename(index = {'Number of Records': 'Brand Female count.'}, inplace = True)

    Brand_Count_M1 = Brand_Count_M
    Brand_Count_M1  = Brand_Count_M1.astype(str).replace('\.0', '', regex=True)
    Brand_M = Brand_Count_M1.transpose()
    Brand_M[''+str(term_average_label)+ ' Year Average'] = Brand_Count_M_3yr_avg
    Brand_M.rename(index = {'Number of Records': 'Brand Male count.'}, inplace = True)

    Brand_gendercount = Brand_gendercount.append(Brand_F)
    Brand_gendercount = Brand_gendercount.append(Brand_M)

    Gender_Graduate_Program_Count = pd.DataFrame()
    Gender_Graduate_Program_Count = Gender_Graduate_Program_Count.append(actv_prog1_gendercount)
    Gender_Graduate_Program_Count = Gender_Graduate_Program_Count.append(Selected_School1_gendercount)
    Gender_Graduate_Program_Count = Gender_Graduate_Program_Count.append(Brand_gendercount)

    ##########THIS BLOCK OF CELL CREATES A TABLE FOR THE COUNT AND THREE YEAR AVERAGE OF ACTIVE PROGRAM1 BY TERM ########
    #################### FOR ETHNICITY ########################
    actv_prog1_ethnicity_count = pd.DataFrame()
    actv_prog_select1_AfrAmr_count1 = actv_prog_select1_AfrAmr_count
    actv_prog_select1_AfrAmr_count1   = actv_prog_select1_AfrAmr_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_afrm = actv_prog_select1_AfrAmr_count1.transpose()
    actv_prog1_afrm[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_AfrAmr_count_3yr_avg
    actv_prog1_afrm.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race1 Chicken Count.'}, inplace=True)

    actv_prog_select1_Asn_count1 = actv_prog_select1_Asn_count
    actv_prog_select1_Asn_count1   = actv_prog_select1_Asn_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_asn = actv_prog_select1_Asn_count1.transpose()
    actv_prog1_asn[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Asn_count_3yr_avg
    actv_prog1_asn.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race2 Chicken Count.'}, inplace = True)

    actv_prog_select1_Wht_count1 = actv_prog_select1_Wht_count
    actv_prog_select1_Wht_count1   = actv_prog_select1_Wht_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_wht = actv_prog_select1_Wht_count1.transpose()
    actv_prog1_wht[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Wht_count_3yr_avg
    actv_prog1_wht.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race6 Chicken Count.'}, inplace = True)

    actv_prog_select1_PcfIsl_count1 = actv_prog_select1_PcfIsl_count
    actv_prog_select1_PcfIsl_count1   = actv_prog_select1_PcfIsl_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_pcfisl = actv_prog_select1_PcfIsl_count1.transpose()
    actv_prog1_pcfisl[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_PcfIsl_count_3yr_avg
    actv_prog1_pcfisl.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race7 Chicken Count.'}, inplace = True)

    actv_prog_select1_Ukn_count1 = actv_prog_select1_Ukn_count
    actv_prog_select1_Ukn_count1   = actv_prog_select1_Ukn_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_ukn = actv_prog_select1_Ukn_count1.transpose()
    actv_prog1_ukn[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Ukn_count_3yr_avg
    actv_prog1_ukn.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Declined to State Chicken Count.'}, inplace = True)

    actv_prog_select1_Hisp_count1 = actv_prog_select1_Hisp_count
    actv_prog_select1_Hisp_count1   = actv_prog_select1_Hisp_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_hisp = actv_prog_select1_Hisp_count1.transpose()
    actv_prog1_hisp[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Hisp_count_3yr_avg
    actv_prog1_hisp.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race3 Chicken Count.'}, inplace = True)

    actv_prog_select1_Int_count1 = actv_prog_select1_Int_count
    actv_prog_select1_Int_count1   = actv_prog_select1_Int_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_int = actv_prog_select1_Int_count1.transpose()
    actv_prog1_int[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_Int_count_3yr_avg
    actv_prog1_int.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race4 Chicken Count.'}, inplace = True)

    actv_prog_select1_NtvAmr_count1 = actv_prog_select1_NtvAmr_count
    actv_prog_select1_NtvAmr_count1   = actv_prog_select1_NtvAmr_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_ntvamr = actv_prog_select1_NtvAmr_count1.transpose()
    actv_prog1_ntvamr[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_NtvAmr_count_3yr_avg
    actv_prog1_ntvamr.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' Race8 Chicken Count.'}, inplace = True)

    actv_prog_select1_UREM_count1 = actv_prog_select1_UREM_count
    actv_prog_select1_UREM_count1   = actv_prog_select1_UREM_count1.astype(str).replace('\.0', '', regex=True)
    actv_prog1_urem = actv_prog_select1_UREM_count1.transpose()
    actv_prog1_urem[''+str(term_average_label)+ ' Year Average'] = actv_prog_select1_UREM_count_3yr_avg
    actv_prog1_urem.rename(index={'Number of Records':''+str(actv_prog_select1_label)+' UREM Chicken Count.'}, inplace = True)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_afrm)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_ntvamr)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_asn)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_pcfisl)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_hisp)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_wht)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_ukn)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_int)
    actv_prog1_ethnicity_count = actv_prog1_ethnicity_count.append(actv_prog1_urem)

    ##########THIS BLOCK OF CELL CREATES A TABLE FOR THE COUNT AND THREE YEAR AVERAGE OF SELECT SCHOOL1 BY TERM ########
    #################### FOR ETHNICITY ########################
    Selected_School1_ethnicity_count = pd.DataFrame()
    Selected_School1_AfrAmr_count1 = Selected_School1_AfrAmr_count
    Selected_School1_AfrAmr_count1   = Selected_School1_AfrAmr_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_afrm = Selected_School1_AfrAmr_count1.transpose()

    Selected_School1_afrm[''+str(term_average_label)+ ' Year Average'] = Selected_School1_AfrAmr_count_3yr_avg
    Selected_School1_afrm.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race1 Chicken Count.'}, inplace=True)

    Selected_School1_Asn_count1 = Selected_School1_Asn_count
    Selected_School1_Asn_count1   = Selected_School1_Asn_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_asn = Selected_School1_Asn_count1.transpose()

    Selected_School1_asn[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Asn_count_3yr_avg
    Selected_School1_asn.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race2 American Chicken Count.'}, inplace = True)

    Selected_School1_Wht_count1 = Selected_School1_Wht_count
    Selected_School1_Wht_count1   = Selected_School1_Wht_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_wht = Selected_School1_Wht_count1.transpose()

    Selected_School1_wht[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Wht_count_3yr_avg
    Selected_School1_wht.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race6 Chicken Count.'}, inplace = True)

    Selected_School1_PcfIsl_count1 = Selected_School1_PcfIsl_count
    Selected_School1_PcfIsl_count1   = Selected_School1_PcfIsl_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_pcfisl = Selected_School1_PcfIsl_count1.transpose()

    Selected_School1_pcfisl[''+str(term_average_label)+ ' Year Average'] = Selected_School1_PcfIsl_count_3yr_avg
    Selected_School1_pcfisl.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race7 Chicken Count.'}, inplace = True)

    Selected_School1_Ukn_count1 = Selected_School1_Ukn_count
    Selected_School1_Ukn_count1   = Selected_School1_Ukn_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_ukn = Selected_School1_Ukn_count1.transpose()

    Selected_School1_ukn[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Ukn_count_3yr_avg
    Selected_School1_ukn.rename(index={'Number of Records':''+str(Selected_School1_label)+' Declined to State Chicken Count.'}, inplace = True)

    Selected_School1_Hisp_count1 = Selected_School1_Hisp_count
    Selected_School1_Hisp_count1   = Selected_School1_Hisp_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_hisp = Selected_School1_Hisp_count1.transpose()

    Selected_School1_hisp[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Hisp_count_3yr_avg
    Selected_School1_hisp.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race3 Chicken Count.'}, inplace = True)

    Selected_School1_Int_count1 = Selected_School1_Int_count
    Selected_School1_Int_count1 = Selected_School1_Int_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_int = Selected_School1_Int_count1.transpose()

    Selected_School1_int[''+str(term_average_label)+ ' Year Average'] = Selected_School1_Int_count_3yr_avg
    Selected_School1_int.rename(index={'Number of Records':''+str(Selected_School1_label)+' Race4 Chicken Count.'}, inplace = True)

    Selected_School1_NtvAmr_count1 = Selected_School1_NtvAmr_count
    Selected_School1_NtvAmr_count1 = Selected_School1_NtvAmr_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_ntvamr = Selected_School1_NtvAmr_count1.transpose()

    Selected_School1_ntvamr[''+str(term_average_label)+ ' Year Average'] = Selected_School1_NtvAmr_count_3yr_avg
    Selected_School1_ntvamr.rename(index={'Number of Records':''+str(Selected_School1_label)+ ' Race8 Chicken Count.'}, inplace = True)

    Selected_School1_UREM_count1 = Selected_School1_UREM_count
    Selected_School1_UREM_count1 = Selected_School1_UREM_count1.astype(str).replace('\.0', '', regex=True)
    Selected_School1_urem = Selected_School1_UREM_count1.transpose()

    Selected_School1_urem[''+str(term_average_label)+ ' Year Average'] = Selected_School1_UREM_count_3yr_avg
    Selected_School1_urem.rename(index={'Number of Records':''+str(Selected_School1_label)+' UREM Chicken Count.'}, inplace = True)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_afrm)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_ntvamr)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_asn)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_pcfisl)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_hisp)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_wht)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_ukn)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_int)
    Selected_School1_ethnicity_count = Selected_School1_ethnicity_count.append(Selected_School1_urem)

    ##########THIS BLOCK OF CELL CREATES A TABLE FOR THE COUNT AND THREE YEAR AVERAGE OF Brand BY TERM ########
    #################### FOR ETHNICITY ########################
    Brand_ethnicity_count = pd.DataFrame()
    Brand_AfrAmr_count1 = Brand_AfrAmr_count
    Brand_AfrAmr_count1 = Brand_AfrAmr_count1.astype(str).replace('\.0', '', regex=True)
    Brand_afrm = Brand_AfrAmr_count1.transpose()

    Brand_afrm[''+str(term_average_label)+ ' Year Average'] = Brand_AfrAmr_count_3yr_avg
    Brand_afrm.rename(index={'Number of Records':'Brand Race1 Chicken Count.'}, inplace=True)

    Brand_Asn_count1 = Brand_Asn_count
    Brand_Asn_count1 = Brand_Asn_count1.astype(str).replace('\.0', '', regex=True)
    Brand_asn = Brand_Asn_count1.transpose()
    Brand_asn[''+str(term_average_label)+ ' Year Average'] = Brand_Asn_count_3yr_avg
    Brand_asn.rename(index={'Number of Records':'Brand Race2 American Chicken Count.'}, inplace = True)

    Brand_Wht_count1 = Brand_Wht_count
    Brand_Wht_count1 = Brand_Wht_count1.astype(str).replace('\.0', '', regex=True)
    Brand_wht = Brand_Wht_count1.transpose()
    Brand_wht[''+str(term_average_label)+ ' Year Average'] = Brand_Wht_count_3yr_avg
    Brand_wht.rename(index={'Number of Records':'Brand Race6 Chicken Count.'}, inplace = True)
    Brand_PcfIsl_count1 = Brand_PcfIsl_count
    Brand_PcfIsl_count1 = Brand_PcfIsl_count1.astype(str).replace('\.0', '', regex=True)
    Brand_pcfisl = Brand_PcfIsl_count1.transpose()
    Brand_pcfisl[''+str(term_average_label)+ ' Year Average'] = Brand_PcfIsl_count_3yr_avg
    Brand_pcfisl.rename(index={'Number of Records':'Brand Race7 Chicken Count.'}, inplace = True)

    Brand_Ukn_count1 = Brand_Ukn_count
    Brand_Ukn_count1 = Brand_Ukn_count1.astype(str).replace('\.0', '', regex=True)
    Brand_ukn = Brand_Ukn_count1.transpose()
    Brand_ukn[''+str(term_average_label)+ ' Year Average'] = Brand_Ukn_count_3yr_avg
    Brand_ukn.rename(index={'Number of Records':'Brand Declined to State Chicken Count.'}, inplace = True)

    Brand_Hisp_count1 = Brand_Hisp_count
    Brand_Hisp_count1 = Brand_Hisp_count1.astype(str).replace('\.0', '', regex=True)
    Brand_hisp = Brand_Hisp_count1.transpose()
    Brand_hisp[''+str(term_average_label)+ ' Year Average'] = Brand_Hisp_count_3yr_avg
    Brand_hisp.rename(index={'Number of Records':'Brand Race3 Chicken Count.'}, inplace = True)

    Brand_Int_count1 = Brand_Int_count
    Brand_Int_count1 = Brand_Int_count1.astype(str).replace('\.0', '', regex=True)
    Brand_int = Brand_Int_count1.transpose()
    Brand_int[''+str(term_average_label)+ ' Year Average'] = Brand_Int_count_3yr_avg
    Brand_int.rename(index={'Number of Records':'Brand Race4 Chicken Count.'}, inplace = True)

    Brand_NtvAmr_count1 = Brand_NtvAmr_count
    Brand_NtvAmr_count1 = Brand_NtvAmr_count1.astype(str).replace('\.0', '', regex=True)
    Brand_ntvamr = Brand_NtvAmr_count1.transpose()
    Brand_ntvamr[''+str(term_average_label)+ ' Year Average'] = Brand_NtvAmr_count_3yr_avg
    Brand_ntvamr.rename(index={'Number of Records':'Brand Race8 Chicken Count.'}, inplace = True)

    Brand_UREM_count1 = Brand_UREM_count
    Brand_UREM_count1 = Brand_UREM_count1.astype(str).replace('\.0', '', regex=True)
    Brand_urem = Brand_UREM_count1.transpose()
    Brand_urem[''+str(term_average_label)+ ' Year Average'] = Brand_UREM_count_3yr_avg
    Brand_urem.rename(index={'Number of Records':'Brand UREM Chicken Count.'}, inplace = True)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_afrm)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_ntvamr)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_asn)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_pcfisl)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_hisp)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_wht)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_ukn)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_int)
    Brand_ethnicity_count = Brand_ethnicity_count.append(Brand_urem)

    Race_Ethnicity_Graduate_Program = pd.DataFrame()
    Race_Ethnicity_Graduate_Program = Race_Ethnicity_Graduate_Program.append(actv_prog1_ethnicity_count)
    Race_Ethnicity_Graduate_Program = Race_Ethnicity_Graduate_Program.append(Selected_School1_ethnicity_count)
    Race_Ethnicity_Graduate_Program = Race_Ethnicity_Graduate_Program.append(Brand_ethnicity_count)

    #Print out dataframes as a report
    styles = [dict(selector="caption", 
        props=[("text-align", "left"),
        ("font-size", "120%"),
        ("color", 'black')])] 
    print("")
    #Graph 1 Actv Prog 1 Count by Term
    print("DATE & TIME OF LAST RUN: ")
    print(datetime.now())
    #print("\n")
    print(bcolors.BOLD+ """1. Chicken COUNT and PERCENTAGES """ + bcolors.ENDC)
    display(actv_prog_.style.set_caption(''+str(actv_prog_select1_label)+' Chicken Count [GRAPH 1]').set_table_styles(styles))
    # %matplotlib inline 
    plt.rcParams["figure.figsize"] = [11,4]
    Graph1 =  actv_prog_select1_count.plot.bar(y='Number of Records', color= 'b')
    plt.title('[GRAPH 1]. '+str(actv_prog_select1_label)+' Count by Fiscal Year.')
    plt.ylabel('Number of Chicken')
    boxs = Graph1.get_position()
    Graph1.set_position([boxs.x0, boxs.y0, boxs.width * 0.8, boxs.height])
    Graph1.legend(loc= 'center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    display(Graduate_Program_Count.style.set_caption(''+str(Selected_School1_label)+' and Coup Count').set_table_styles(styles))
    display(Graduate_Program_Count_Percentages.style.set_caption('Percent of Department Enrolled sChicken in '+str(Selected_School1_label)+' and Brand by Term. [GRAPH 2]').set_table_styles(styles))

    #Graph 2 Percent of Actv Prog1 in Divisions
    # %matplotlib inline 
    plt.rcParams["figure.figsize"] = [11,4]
    Selected_School1_div_actv_prog_dummy = Selected_School1_div_actv_prog*100
    Brand_Count_by_term_div_actv_prog_dummy = Brand_Count_by_term_div_actv_prog*100
    Selected_School1_div_actv_prog_dummy['Key']= '1. '+str(Selected_School1_label)+''
    Brand_Count_by_term_div_actv_prog_dummy['Key']= '2. Brand'
    Graph2 = pd.concat([Selected_School1_div_actv_prog_dummy, Brand_Count_by_term_div_actv_prog_dummy], keys = ['1. Selected School1', '2. Brand'])
    Graph2 = Graph2.groupby(['Fiscal Year','Key'])
    Graph2 = Graph2.sum().unstack('Key').plot(kind='bar', color=['g','r'])
    formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
    Graph2.yaxis.set_major_formatter(formatter)
    plt.title('[GRAPH 2]. Percent of '+str(actv_prog_select1_label)+' in Divisions')
    plt.ylabel('Percent of Chicken')
    box2 = Graph2.get_position()
    Graph2.set_position([box2.x0, box2.y0, box2.width * 0.8, box2.height])
    Graph2.legend(loc= 'center left', bbox_to_anchor=(1, 0.5))
    plt.show()

    print(bcolors.BOLD+ """2. GENDER COUNT and PERCENTAGES """ + bcolors.ENDC)
    display(actv_prog1_gendercount.style.set_caption('Gender Count for '+str(actv_prog_select1_label)+' by Fiscal Year.').set_table_styles(styles))
    display(Selected_School1_gendercount.style.set_caption('Gender Count for ' +str(Selected_School1_label)+' by Fiscal Year.').set_table_styles(styles))
    display(Brand_gendercount.style.set_caption('Gender Count for Brand by Fiscal Year.').set_table_styles(styles))    
    display(act_prog_gender_percentages.style.set_caption('Gender Percentages for '+str(actv_prog_select1_label)+' by Fiscal Year. [GRAPH 3]').set_table_styles(styles))

    #Graph 3 Graduates Percent Gender: Actv Prog 1
    plt.rcParams["figure.figsize"] = [11,4]
    actv_prog_select1_F_div_all_dummy = actv_prog_select1_F_div_all*100
    actv_prog_select1_M_div_all_dummy = actv_prog_select1_M_div_all*100
    actv_prog_select1_M_div_all_dummy['Key'] = '1. Male '+str(actv_prog_select1_label)+''
    actv_prog_select1_F_div_all_dummy['Key'] = '2. Female '+str(actv_prog_select1_label)+''
    Graph3 = pd.concat([actv_prog_select1_M_div_all_dummy, actv_prog_select1_F_div_all_dummy],keys=['1. Male Actv Prog','2. Female Actv Prog'])
    Graph3 = Graph3.groupby(['Fiscal Year','Key'])
    Graph3 = Graph3.sum().unstack('Key').plot(kind='bar', color=['b','m'])
    formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
    Graph3.yaxis.set_major_formatter(formatter)
    plt.title('[GRAPH 3]. Graduates Percent Gender: '+str(actv_prog_select1_label)+'')
    plt.ylabel('Percent of Chicken')
    box1 = Graph3.get_position()
    Graph3.set_position([box1.x0, box1.y0, box1.width * 0.8, box1.height])
    Graph3.legend(['Male', 'Female'])
    Graph3.legend(loc= 'center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    display(selected_school_gender_percentages.style.set_caption('Gender Percentages for '+str(Selected_School1_label)+' by Fiscal Year [GRAPH 4]').set_table_styles(styles))

    #Graph 4
    plt.rcParams["figure.figsize"] = [11,4]
    Selected_School1_F_div_all_dummy = Selected_School1_F_div_all*100
    Selected_School1_M_div_all_dummy = Selected_School1_M_div_all*100
    Selected_School1_M_div_all_dummy['Key'] = '1. Male '+str(Selected_School1_label)+''
    Selected_School1_F_div_all_dummy['Key'] = '2. Female '+str(Selected_School1_label)+''
    Graph4 = pd.concat([Selected_School1_M_div_all_dummy, Selected_School1_F_div_all_dummy],keys=['1. Male Selected School','2. Female Selected School'])
    Graph4 = Graph4.groupby(['Fiscal Year','Key'])
    Graph4 = Graph4.sum().unstack('Key').plot(kind='bar',color=['g','m'])
    formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
    Graph4.yaxis.set_major_formatter(formatter)
    plt.title('[GRAPH 4]. Graduates Percent Gender: '+str(Selected_School1_label)+'')
    plt.ylabel('Percent of Brand')
    box1 = Graph4.get_position()
    Graph4.set_position([box1.x0, box1.y0, box1.width * 0.8, box1.height])
    Graph4.legend(['Male', 'Female'])
    Graph4.legend(loc= 'center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    display(Brand_gender_percentages.style.set_caption('Gender Percentages for Brand. [GRAPH 5]').set_table_styles(styles))

    #Graph 5 Graduates Percent Gender: Brand
    plt.rcParams["figure.figsize"] = [11,4]
    Brand_F_div_all_dummy = Brand_Count_F_div_all*100
    Brand_M_div_all_dummy = Brand_Count_M_div_all*100
    Brand_M_div_all_dummy['Key'] = '1. Male Brand'
    Brand_F_div_all_dummy['Key'] = '2. Female Brand'
    Graph5 = pd.concat([Brand_M_div_all_dummy, Brand_F_div_all_dummy],keys=['1. Male Brand','2. Female Brand'])
    Graph5 = Graph5.groupby(['Fiscal Year','Key'])
    Graph5 = Graph5.sum().unstack('Key').plot(kind='bar',color=['r','m'])
    formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
    Graph5.yaxis.set_major_formatter(formatter)
    plt.title('[GRAPH 5]. Graduates Percent Gender: Brand')
    plt.ylabel('Percent of Brand')
    box2 = Graph5.get_position()
    Graph5.set_position([box2.x0, box2.y0, box2.width * 0.8, box2.height])
    Graph5.legend(['Male', 'Female'])
    Graph5.legend(loc= 'center left', bbox_to_anchor=(1, 0.5))
    plt.show()

    print(bcolors.BOLD+ """3. ETHNICITY COUNT and PERCENTAGES """ + bcolors.ENDC)
    display(actv_prog1_ethnicity_count.style.set_caption('Ethnicity Count for ' +str(actv_prog_select1_label)+' by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)
    display(Selected_School1_ethnicity_count.style.set_caption('Ethnicity Count for ' +str(Selected_School1_label)+' by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)
    display(Brand_ethnicity_count.style.set_caption('Ethnicity Count for Brand by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)

    display(act_prog_ethnicity_percentages.style.set_caption('Ethnicity Percentages for '+str(actv_prog_select1_label)+' by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)
    display(Selected_School1_ethnicity_percentages.style.set_caption('Ethnicity Percentages for '+str(Selected_School1_label)+' by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)
    display(Brand_ethnicity_percentages.style.set_caption('Ethnicity Percentages for Brand by Term').set_table_styles(styles))
    print(bcolors.FAIL+ """NOTE: UREM= Race7, Race3, Race8, and Race1 Chicken in the count. """  + bcolors.ENDC)
    display(UREM_percentages.style.set_caption('UREM Percentages for '+str(actv_prog_select1_label)+', '+str(Selected_School1_label)+' and Brand. [GRAPH 6]').set_table_styles(styles))

    
    print("END OF REPORTING FOR "+str(actv_prog_select1_label)+".")
    ##############PROGRAM CELL###############PROGRAM CELL###############PROGRAM CELL#####################PROGAM CELL###


######################################DO NOT TOUCH################################################################
######################################DO NOT TOUCH################################################################

# %%
#Step1 Generate and format data for SU/WI, SP/FA
#generate dataframe for SUWI data
acad = pd.DataFrame()
for i in listofacadlevel:
    ab = acadlevel_select(df2, i)
    acad= acad.append(ab, ignore_index= True)
    acad = pd.DataFrame(acad)  
    

termsr = pd.DataFrame()
for i in listoftermsA:
    cd = term_select(acad, i)
    termsr = termsr.append(cd, ignore_index= True)
    termsr = pd.DataFrame(termsr)

cleandataSUWI = termsr

# %%
#Step2 Variables
Prod1step2, Prod1replacement = Step2(cleandataSUWI, 'Product 1', 'Product 1')
Prod2step2, Prod2replacement = Step2(cleandataSUWI, 'Product 2', 'Product 2')
Prod3step2, Prod3replacement = Step2(cleandataSUWI, 'Product 3', 'Product 3')
#OnlMBAstep2, OnlMBAreplacement = Step2(cleandataSUWI, "OnlMBA", "OnlineMBAProgram")

# %%
def ONE_AT_A_TIME(argument):
    if argument == 'Product1': 
         Step3A(listoftermsA, "Line 1", cleandataSUWI, Prod1replacement, Prod1step2)
    elif argument == 'Product2': 
         Step3A(listoftermsA, "Line 1", cleandataSUWI, Prod2replacement, Prod2step2)
    elif argument == 'Product3': 
         Step3A(listoftermsA, "Line 1", cleandataSUWI, Prod3replacement, Prod3step2)
    elif argument == 'Product4': 
         Step3A(listoftermsA, "Line 1", cleandataSUWI, Prod4replacement, Prod4step2)
    else:
        print('Invalid Entry')

# %%
#takes user input from input widget and runs Step3A function on the selection generating reports
ONE_AT_A_TIME(ProgRev[0])
# Out:
# Invalid Entry

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
